# %%
import os
# CUDA_VISIBLE_DEVICES = "0,1,2,3,4,5,6,7"
# CUDA_VISIBLE_DEVICES = "0,1,2,3"
# CUDA_VISIBLE_DEVICES = "0,1"
CUDA_VISIBLE_DEVICES = "0,1"
os.environ["CUDA_VISIBLE_DEVICES"] = CUDA_VISIBLE_DEVICES

os.environ['XLA_PYTHON_CLIENT_PREALLOCATE'] = 'false'
os.environ['JAX_PLATFORM_NAME'] = 'gpu'

NPROC = len(CUDA_VISIBLE_DEVICES.split(","))

# %%
import sys
sys.path.insert(0, "/home/jovyan/d-shlenskii/repos/skyloop/ott/src")

# %%
# import shutup
# shutup.please()

import warnings
warnings.filterwarnings('ignore')

# import rootutils
# ROOT = rootutils.setup_root(indicator='README.md', search_from=os.path.abspath(''), pythonpath=True, cwd=True)

import jax
import jax.numpy as jnp
import optax
from jaxtyping import ArrayLike, Float
import numpy as np
GLOBAL_KEY = jax.random.key(42)

import seaborn as sns
import matplotlib.pyplot as plt
# plt.style.use(['science', 'notebook'])

# Lagrangian Potentials

from ott2.neural.methods.lagrangian.lagrangian_potentials import *

# %load_ext autoreload
# %autoreload 2

# %%
## Utils

def draw_trajs(trajs: Float[ArrayLike, 'timestep point dim=2'], ax=None):
    if ax is None:
        fig, ax = plt.subplots()
    colors = sns.color_palette("pastel", trajs.shape[1])
    
    for point in range(trajs.shape[1]):
        for t in range(1, trajs.shape[0]):
            ax.plot([trajs[t-1, point, 0], trajs[t, point, 0]],
                    [trajs[t-1, point, 1], trajs[t, point, 1]],
                    color=colors[point], linestyle="-", linewidth=1, marker='o', alpha=0.6, markersize=1)
    return ax

# %%
# Multigpu utils
from jax.sharding import Mesh
from jax.sharding import PartitionSpec
from jax.sharding import NamedSharding
from jax.experimental import mesh_utils

P = PartitionSpec
mesh = Mesh(mesh_utils.create_device_mesh((NPROC,)), axis_names=('data',))

def with_mesh(f):
    def wrapper(*args, **kwargs):
        with mesh:
            return f(*args, **kwargs)
    return wrapper

# %%
from torch.utils.data import Dataset, DataLoader

class InfiniteLoaderWrapper:
    def __init__(self, loader: DataLoader):
        self.loader = loader
        self.loader_it = iter(loader)
    
    def __iter__(self):
        self.loader_it = iter(self.loader)
        return self

    def __next__(self):
        try:
            batch = next(self.loader_it)
        except StopIteration:
            self.loader_it = iter(self.loader)
            batch = next(self.loader_it)
        return batch

class OTLoader:
    def __init__(
        self,
        src_ds: Dataset,
        trg_ds: Dataset,
        flatten_flag: bool = False,
        **torch_dataloader_kwargs,
    ):
        def collate_fn(batch: tuple[np.ndarray]):
            return np.stack(batch)

        self.src_loader = InfiniteLoaderWrapper(DataLoader(src_ds, collate_fn=collate_fn, **torch_dataloader_kwargs))
        self.trg_loader = InfiniteLoaderWrapper(DataLoader(trg_ds, collate_fn=collate_fn, **torch_dataloader_kwargs))
        self.flatten_flag = flatten_flag

    def __iter__(self):
        self.src_loader = iter(self.src_loader)
        self.trg_loader = iter(self.trg_loader)
        return self

    def __next__(self):
        src_batch = jnp.asarray(next(self.src_loader))
        tgt_batch = jnp.asarray(next(self.trg_loader))
        if self.flatten_flag:
            b_size = src_batch.shape[0]
            src_batch = src_batch.reshape(b_size, -1)
            tgt_batch = tgt_batch.reshape(b_size, -1)
        return {
            "src_lin": src_batch,
            "tgt_lin": tgt_batch,
        }

# %% [markdown]
# # Neural

# %%
import flax.linen as nn

# %%
class MLP(nn.Module):
    hidden_layers: list
    
    @nn.compact
    def __call__(self, t, x, _):
        x = jnp.concatenate([x, t], -1)
        for i, dim in enumerate(self.hidden_layers):
            x = nn.Dense(dim)(x)
            if i != len(self.hidden_layers) - 1:
                x = nn.leaky_relu(x)
        return x

# %%
from ott2.neural.networks.resnet_d import ResNet_D


class ResNetDwTime(nn.Module):
    size: int = 64 
    nlayers: int = 4
    nc: int = 3
    nfilter: int = 64
    nfilter_max: int = 512

    @nn.compact
    def __call__(self, t, x, train=True):
        b_size = t.shape[0]

        x = x.reshape(-1, self.nc, self.size, self.size)

        t_emb = nn.Dense(self.size**2)(t[:, None]) # [b, size**2]
        t_emb = t_emb.reshape(b_size, 1, self.size, self.size)

        x_with_t = jnp.concatenate([x, t_emb], axis=1)
        return ResNet_D(
            size=self.size,
            nlayers=self.nlayers,
            nc=self.nc+1,
            nfilter=self.nfilter,
            nfilter_max=self.nfilter_max,
        )(x_with_t)

# %%
from functools import partial
from flax.training.train_state import TrainState

@with_mesh
@partial(jax.jit, static_argnums=(0, 1))
def create_state(module: nn.Module, dim: int):
    variables = module.init(
        jax.random.PRNGKey(0),
        np.random.randn(1, 1),
        np.random.randn(1, dim),
        np.random.randn(1, dim),
    )
    state = TrainState.create(
        apply_fn=module.apply,
        params=variables["params"],
        tx=optax.adamw(3e-4),
    )
    state = jax.tree_map(jnp.asarray, state)
    state_spec = nn.get_partition_spec(state)
    state = jax.lax.with_sharding_constraint(state, state_spec)
    return state

module = MLP(hidden_layers=(128, 1))
state = create_state(module, dim=2)
jax.tree_map(jnp.shape, state)
jax.debug.visualize_array_sharding(state.params["Dense_0"]["kernel"])
# Out:
#
#
#
#
#
#                                     GPU 0,1

# %% [markdown]
# # Neural Optimal Control

# %%
import numpy as np

from ott2.neural.methods.nocc import NeuralOC
from ott2.neural.methods.flows.dynamics import LagrangianFlow
from IPython.display import clear_output

from flax.struct import PyTreeNode

# %%
class LagrangianPotentialFree(PyTreeNode):
    @abstractmethod
    def __call__(self, x):
        return 0.

# %% [markdown]
# ## Gaussians (high dimensional)

# %%
# %load_ext autoreload
# %autoreload 2

# # dataset params
# ds_size = 20_000
# # ds_dim = 3 * 64**2
# ds_dim = 2
# sigma = 0.1

# # training params
# batch_size = 512
# n_iters = 1_000_000
# collect_buffer_iters = 2_000
# update_potential_every = 4


# src_mu = -np.ones(ds_dim)
# trg_mu = np.ones(ds_dim)

# ot_loader = OTLoader(
#     src_ds=np.random.randn(ds_size, ds_dim) * sigma + src_mu,
#     trg_ds=np.random.randn(ds_size, ds_dim) * sigma + trg_mu,
#     shuffle=True,
#     batch_size=batch_size,
# )
# ot_loader = iter(ot_loader)

# potential_data_loader = iter(ot_loader)
# potential = LagrangianPotentialFree()

# def callback(step, training_logs, transport):
#     clear_output()
#     pi0 = next(potential_data_loader)['src_lin']
#     pi1 = next(potential_data_loader)['tgt_lin']

#     cost, trajs = transport(pi0)

#     fig, ax = plt.subplots()
#     ax.scatter(pi0[:,0], pi0[:, 1], c='red', alpha=1, s=4)
#     ax.scatter(pi1[:,0], pi1[:, 1], c='black', alpha=0.5, s=10)
#     ax.scatter(trajs[-1].x[:, 0], trajs[-1].x[:, 1], c='green', s=10)
#     ax.set_xlim((-1.5, 1.5))
#     ax.set_ylim((-1.5, 1.5))
#     draw_trajs(trajs=jnp.stack([traj.x for traj in trajs])[:, :100], ax=ax)
#     plt.show()
     
# net = MLP(hidden_layers=[256, 256, 256, 1])
# num_iterations = n_iters
# noc = NeuralOC(
#     input_dim=ds_dim, 
#     value_model=net, 
#     optimizer=optax.adam(learning_rate=1e-4), 
#     control_steps=30,
#     reg_weight=0.,
#     control_weight=100., 
#     acc_weight=0.,
#     potential_weight=0., 
#     flow=LagrangianFlow(sigma=0.1, potential=potential), 
#     key=GLOBAL_KEY,
#     batch_size=batch_size,
# )

# logs = noc(
#     potential_data_loader,
#     n_iters=num_iterations,
#     rng=GLOBAL_KEY,
#     callback=callback,
#     collect_buffer_iters=collect_buffer_iters,
#     update_potential_every=update_potential_every,
# )

# %% [markdown]
# ## Three Gaussians

# %%
# %load_ext autoreload
# %autoreload 2

# dataset params
ds_size = 20_000
# ds_dim = 3 * 64**2
ds_dim = 1024
sigma = 0.1

# training params
batch_size = 512
n_iters = 1_000_000
collect_buffer_iters = 1_000_000
update_potential_every = 4

src_mu = np.zeros(ds_dim)
trg_mu1 = np.ones(ds_dim)
trg_mu2 = -np.ones(ds_dim)

ot_loader = OTLoader(
    src_ds=np.random.randn(ds_size, ds_dim) * sigma + src_mu,
    trg_ds=np.concatenate([
        np.random.randn(ds_size//2, ds_dim) * sigma + trg_mu1,
        np.random.randn(ds_size//2, ds_dim) * sigma + trg_mu2,
    ]),
    shuffle=True,
    batch_size=batch_size,
    drop_last=True,
)
ot_loader = iter(ot_loader)

potential_data_loader = iter(ot_loader)
potential = LagrangianPotentialFree()

def callback(step, training_logs, transport):
    clear_output()
    pi0 = next(potential_data_loader)['src_lin']
    pi1 = next(potential_data_loader)['tgt_lin']

    cost, trajs = transport(pi0)

    fig, ax = plt.subplots()
    ax.scatter(pi0[:,0], pi0[:, 1], c='red', alpha=1, s=4)
    ax.scatter(pi1[:,0], pi1[:, 1], c='black', alpha=0.5, s=10)
    ax.scatter(trajs[-1].x[:, 0], trajs[-1].x[:, 1], c='green', s=10)
    ax.set_xlim((-1.5, 1.5))
    ax.set_ylim((-1.5, 1.5))
    draw_trajs(trajs=jnp.stack([traj.x for traj in trajs])[:, :100], ax=ax)
    plt.show()
     
net = MLP(hidden_layers=[256, 256, 256, 1])
num_iterations = n_iters
noc = NeuralOC(
    input_dim=ds_dim, 
    value_model=net, 
    optimizer=optax.adam(learning_rate=1e-4, b1=0.5, b2=0.5), 
    control_steps=30,
    reg_weight=0.,
    control_weight=0.025,
    acc_weight=0.,
    potential_weight=0., 
    flow=LagrangianFlow(sigma=0., potential=potential), 
    key=GLOBAL_KEY,
    batch_size=batch_size,
)

logs = noc(
    potential_data_loader,
    n_iters=num_iterations,
    rng=GLOBAL_KEY,
    callback=callback,
    collect_buffer_iters=collect_buffer_iters,
    update_potential_every=update_potential_every,
)
# Out:
#   3%|▎         | 30000/1000000 [06:21<3:25:49, 78.54it/s, pot_loss=-544.1348, cost_loss=539.70325]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 67
#      52 num_iterations = n_iters
#      53 noc = NeuralOC(
#      54     input_dim=ds_dim,
#      55     value_model=net,
#    (...)     64     batch_size=batch_size,
#      65 )
# ---> 67 logs = noc(
#      68     potential_data_loader,
#      69     n_iters=num_iterations,
#      70     rng=GLOBAL_KEY,
#      71     callback=callback,
#      72     collect_buffer_iters=collect_buffer_iters,
#      73     update_potential_every=update_potential_every,
#      74 )
#
# File ~/d-shlenskii/repos/skyloop/ott/src/ott2/neural/methods/nocc.py:369, in NeuralOC.__call__(self, loader, n_iters, collect_buffer_iters, update_potential_every, rng, callback, eval_every, save_dir)
#     366 self.buffer.append(x=x_seq, t=t_seq)
#     368 if it % eval_every == 0 and it > 0 and callback is not None:
# --> 369   callback(it, training_logs, self.transport)
#     370   pbar.set_postfix({"pot_loss": loss_potential,
#     371                     "cost_loss": loss})
#     372   if save_dir is not None:
#
# Cell In[18], line 40, in callback(step, training_logs, transport)
#      37 pi0 = next(potential_data_loader)['src_lin']
#      38 pi1 = next(potential_data_loader)['tgt_lin']
# ---> 40 cost, trajs = transport(pi0)
#      42 fig, ax = plt.subplots()
#      43 ax.scatter(pi0[:,0], pi0[:, 1], c='red', alpha=1, s=4)
#
# File ~/d-shlenskii/repos/skyloop/ott/src/ott2/neural/methods/nocc.py:427, in NeuralOC.transport(self, x, condition, **kwargs)
#     424   (_, _, cost, _), result = jax.lax.scan(move, (t_0, x_0, 0.0, loop_key), None, length=n)
#     425   return cost, result
# --> 427 cost, result = inference(self.state, x)
#     428 x_seq = [TimedX(t=t_0, x=x)]
#     430 for i in range(n):
#
# File ~/d-shlenskii/repos/skyloop/ott/src/ott2/neural/methods/nocc.py:66, in with_mesh.<locals>.wrapper(*args, **kwargs)
#      64 def wrapper(*args, **kwargs):
#      65     with mesh:
# ---> 66         return f(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/d-shlenskii/miniconda3/envs/ott/lib/python3.11/site-packages/jax/_src/pjit.py:339, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     334 if config.no_tracing.value:
#     335   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     336                      "`jit`, but 'no_tracing' is set")
#     338 (outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked, executable,
# --> 339  pgle_profiler) = _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     341 maybe_fastpath_data = _get_fastpath_data(
#     342     executable, out_tree, args_flat, out_flat, attrs_tracked, jaxpr.effects,
#     343     jaxpr.consts, jit_info.abstracted_axes,
#     344     pgle_profiler)
#     346 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/d-shlenskii/miniconda3/envs/ott/lib/python3.11/site-packages/jax/_src/pjit.py:194, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     192   args_flat = map(core.full_lower, args_flat)
#     193   core.check_eval_args(args_flat)
# --> 194   out_flat, compiled, profiler = _pjit_call_impl_python(*args_flat, **p.params)
#     195 else:
#     196   out_flat = pjit_p.bind(*args_flat, **p.params)
#
# File ~/d-shlenskii/miniconda3/envs/ott/lib/python3.11/site-packages/jax/_src/pjit.py:1659, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1647 compiler_options_kvs = compiler_options_kvs + tuple(pgle_compile_options.items())
#    1648 # Passing mutable PGLE profile here since it should be extracted by JAXPR to
#    1649 # initialize the fdo_profile compile option.
#    1650 compiled = _resolve_and_lower(
#    1651     args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1652     out_shardings=out_shardings, in_layouts=in_layouts,
#    1653     out_layouts=out_layouts, donated_invars=donated_invars,
#    1654     ctx_mesh=ctx_mesh, name=name, keep_unused=keep_unused,
#    1655     inline=inline, lowering_platforms=None,
#    1656     lowering_parameters=mlir.LoweringParameters(),
#    1657     pgle_profiler=pgle_profiler,
#    1658     compiler_options_kvs=compiler_options_kvs,
# -> 1659 ).compile()
#    1661 # This check is expensive so only do it if enable_checks is on.
#    1662 if compiled._auto_spmd_lowering and config.enable_checks.value:
#
# File ~/d-shlenskii/miniconda3/envs/ott/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:2448, in MeshComputation.compile(self, compiler_options)
#    2446 compiler_options_kvs = self._compiler_options_kvs + t_compiler_options
#    2447 if self._executable is None or compiler_options_kvs:
# -> 2448   executable = UnloadedMeshExecutable.from_hlo(
#    2449       self._name, self._hlo, **self.compile_args,
#    2450       compiler_options_kvs=compiler_options_kvs)
#    2451   if not compiler_options_kvs:
#    2452     self._executable = executable
#
# File ~/d-shlenskii/miniconda3/envs/ott/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:2967, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    2964       break
#    2966 util.test_event("pxla_cached_compilation")
# -> 2967 xla_executable = _cached_compilation(
#    2968     hlo, name, mesh, spmd_lowering,
#    2969     tuple_args, auto_spmd_lowering, allow_prop_to_inputs,
#    2970     allow_prop_to_outputs, tuple(host_callbacks), backend, da, pmap_nreps,
#    2971     compiler_options_kvs, pgle_profiler)
#    2973 orig_out_shardings = out_shardings
#    2975 if auto_spmd_lowering:
#
# File ~/d-shlenskii/miniconda3/envs/ott/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:2758, in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, allow_prop_to_inputs, allow_prop_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_kvs, pgle_profiler)
#    2750 compile_options = create_compile_options(
#    2751     computation, mesh, spmd_lowering, tuple_args, auto_spmd_lowering,
#    2752     allow_prop_to_inputs, allow_prop_to_outputs, backend,
#    2753     dev, pmap_nreps, compiler_options)
#    2755 with dispatch.log_elapsed_time(
#    2756     "Finished XLA compilation of {fun_name} in {elapsed_time:.9f} sec",
#    2757     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2758   xla_executable = compiler.compile_or_get_cached(
#    2759       backend, computation, dev, compile_options, host_callbacks,
#    2760       pgle_profiler)
#    2761 return xla_executable
#
# File ~/d-shlenskii/miniconda3/envs/ott/lib/python3.11/site-packages/jax/_src/compiler.py:470, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks, pgle_profiler)
#     468 else:
#     469   log_persistent_cache_miss(module_name, cache_key)
# --> 470   return _compile_and_write_cache(
#     471       backend,
#     472       computation,
#     473       compile_options,
#     474       host_callbacks,
#     475       module_name,
#     476       cache_key,
#     477   )
#
# File ~/d-shlenskii/miniconda3/envs/ott/lib/python3.11/site-packages/jax/_src/compiler.py:687, in _compile_and_write_cache(backend, computation, compile_options, host_callbacks, module_name, cache_key)
#     678 def _compile_and_write_cache(
#     679     backend: xc.Client,
#     680     computation: ir.Module,
#    (...)    684     cache_key: str,
#     685 ) -> xc.LoadedExecutable:
#     686   start_time = time.monotonic()
# --> 687   executable = backend_compile(
#     688       backend, computation, compile_options, host_callbacks
#     689   )
#     690   compile_time = time.monotonic() - start_time
#     691   _cache_write(
#     692       cache_key, compile_time, module_name, backend, executable, host_callbacks
#     693   )
#
# File ~/d-shlenskii/miniconda3/envs/ott/lib/python3.11/site-packages/jax/_src/profiler.py:334, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     331 @wraps(func)
#     332 def wrapper(*args, **kwargs):
#     333   with TraceAnnotation(name, **decorator_kwargs):
# --> 334     return func(*args, **kwargs)
#     335   return wrapper
#
# File ~/d-shlenskii/miniconda3/envs/ott/lib/python3.11/site-packages/jax/_src/compiler.py:321, in backend_compile(backend, module, options, host_callbacks)
#     315     return backend.compile(
#     316         built_c, compile_options=options, host_callbacks=host_callbacks
#     317     )
#     318   # Some backends don't have `host_callbacks` option yet
#     319   # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     320   # to take in `host_callbacks`
# --> 321   return backend.compile(built_c, compile_options=options)
#     322 except xc.XlaRuntimeError as e:
#     323   for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Images example

# %%
from torch.utils.data import Subset, DataLoader, Dataset, ConcatDataset
from torchvision.transforms import Compose, Resize, Normalize, ToTensor, RandomCrop, RandomHorizontalFlip, RandomVerticalFlip, Lambda, Pad, CenterCrop, RandomResizedCrop
from torchvision.datasets import ImageFolder

class MyImageFolder(ImageFolder):
    def __getitem__(self, idx: int):
        return super().__getitem__(idx)[0].numpy()

img_size = 64

# anime dataset
path = "/home/jovyan/nazar/aligned_anime_faces"
transform = Compose([Resize((img_size, img_size)), ToTensor(), Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
anime_dataset = MyImageFolder(path, transform=transform)

# celeba female dataset
path = "/home/jovyan/nazar/celeba_female"
attrs_path = "/home/jovyan/nazar/list_attr_celeba.txt" 
transform = Compose([Resize((img_size, img_size)), ToTensor(), Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
celeba_female_dataset = MyImageFolder(path, transform=transform)

with open(attrs_path, 'r') as f:
    lines = f.readlines()[1:]
idx = [i for i in list(range(len(lines))) if lines[i].replace('  ', ' ').split(' ')[21] == '-1']
print("celeba", len(idx), len(lines), len(celeba_female_dataset))

celeba_female_dataset = Subset(celeba_female_dataset, idx)

# %%
# training params
batch_size = 64
n_iters = 1_000_000
collect_buffer_iters = 10_000
update_potential_every = 2
eval_every = 2_000

nc, dim = 3, 64
ds_dim = nc * dim**2

#
ot_loader = OTLoader(
    src_ds=anime_dataset,
    trg_ds=celeba_female_dataset,
    flatten_flag=True,
    shuffle=True,
    batch_size=batch_size,
    num_workers=4,
    drop_last=True,
)
ot_loader = iter(ot_loader)

potential_data_loader = iter(ot_loader)
potential = LagrangianPotentialFree()

def callback(step, training_logs, transport):
    clear_output()
    pi0 = next(potential_data_loader)['src_lin']
    pi1 = next(potential_data_loader)['tgt_lin']

    cost, trajs = transport(pi0)

    fig, axes = plt.subplots(1, 3, figsize=(12, 4))

    def to_range(image):
        image -= image.min()
        return image / image.max()

    axes[0].imshow(to_range(pi0[0]).reshape(nc, img_size, img_size).transpose(1, 2, 0))
    axes[0].set_title('Source')
    axes[0].axis('off')

    axes[1].imshow(to_range(trajs[-1].x[0]).reshape(nc, img_size, img_size).transpose(1, 2, 0))
    axes[1].set_title('SourceMapped')
    axes[1].axis('off')

    axes[2].imshow(to_range(pi1[0]).reshape(nc, img_size, img_size).transpose(1, 2, 0))
    axes[2].set_title('Target')
    axes[2].axis('off')
    
    plt.show()
     
net = ResNetDwTime(size=dim, nc=nc)
num_iterations = n_iters
lr_schedule = optax.cosine_decay_schedule(
    init_value=2e-5, decay_steps=num_iterations, alpha=1e-2
)
noc = NeuralOC(
    input_dim=ds_dim, 
    value_model=net, 
    optimizer=optax.adam(learning_rate=lr_schedule), 
    control_steps=30,
    reg_weight=0.001,
    control_weight=0.1, 
    acc_weight=0.5,
    potential_weight=0., 
    flow=LagrangianFlow(sigma=0.1, potential=potential), 
    key=GLOBAL_KEY,
    batch_size=batch_size,
)

logs = noc(
    potential_data_loader,
    n_iters=num_iterations,
    rng=GLOBAL_KEY,
    callback=callback,
    collect_buffer_iters=collect_buffer_iters,
    update_potential_every=update_potential_every,
    eval_every=eval_every,
)
